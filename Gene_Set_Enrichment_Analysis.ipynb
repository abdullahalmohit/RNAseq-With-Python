# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahalmohit/RNAseq-With-Python/blob/main/Gene_Set_Enrichment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Data Preparation, load annotated DEseq from DEA analysis

# %%
df = pd.read_csv('/content/DESeq2_results_T_vs_C_annotated.csv').dropna()
df = df.rename(columns = {'Symbol': 'Gene'})

# %%
df
# Out:
#           Geneid      baseMean  log2FoldChange     lfcSE       stat  \
# 0      AT1G01010   2783.409773        0.904959  0.116650   7.757910
# 1      AT1G01020   2982.724194        0.437000  0.189795   2.302478
# 2      AT1G01030     89.240373        0.408271  0.253054   1.613375
# 3      AT1G01040   2262.951462       -0.587789  0.100755  -5.833864
# 4      AT1G01046     16.149035       -1.005451  0.571428  -1.759540
# ...          ...           ...             ...       ...        ...
# 27365  AT5G67600  17265.176792        1.956396  0.193561  10.107378
# 27366  AT5G67610   1938.263024        0.327128  0.115330   2.836467
# 27367  AT5G67620   1305.623526       -1.459157  0.163689  -8.914178
# 27368  AT5G67630   2565.535088        0.065068  0.116319   0.559398
# 27369  AT5G67640    270.795090       -0.169226  0.161161  -1.050041
#
#              pvalue          padj        Gene  \
# 0      8.634049e-15  7.203149e-14      NAC001
# 1      2.130821e-02  4.121231e-02        ARV1
# 2      1.066631e-01  1.673376e-01        NGA3
# 3      5.415823e-09  2.826062e-08        DCL1
# 4      7.848588e-02  1.290246e-01  ath-MIR838
# ...             ...           ...         ...
# 27365  5.123711e-24  7.698072e-23        WIH1
# 27366  4.561573e-03  1.036210e-02   AT5G67610
# 27367  4.914496e-19  5.519193e-18   AT5G67620
# 27368  5.758900e-01  6.704053e-01   AT5G67630
# 27369  2.936992e-01  3.937147e-01   AT5G67640
#
#                                              Description
# 0      NAC domain containing protein 1 [Source:NCBI g...
# 1      ARV1 family protein [Source:NCBI gene (formerl...
# 2      AP2/B3-like transcriptional factor family prot...
# 3      dicer-like 1 [Source:NCBI gene (formerly Entre...
# 4              ath-MIR838 [Source:miRBase;Acc:MI0005394]
# ...                                                  ...
# 27365  cysteine-rich TM module stress tolerance prote...
# 27366  transmembrane protein (DUF2215) [Source:NCBI g...
# 27367  DUF4228 domain protein [Source:NCBI gene (form...
# 27368  P-loop containing nucleoside triphosphate hydr...
# 27369  uncharacterized protein [Source:NCBI gene (for...
#
# [21511 rows x 9 columns]

# %%
df = df.drop(columns= 'Description')

# %%
df
# Out:
#           Geneid      baseMean  log2FoldChange     lfcSE       stat  \
# 0      AT1G01010   2783.409773        0.904959  0.116650   7.757910
# 1      AT1G01020   2982.724194        0.437000  0.189795   2.302478
# 2      AT1G01030     89.240373        0.408271  0.253054   1.613375
# 3      AT1G01040   2262.951462       -0.587789  0.100755  -5.833864
# 4      AT1G01046     16.149035       -1.005451  0.571428  -1.759540
# ...          ...           ...             ...       ...        ...
# 27365  AT5G67600  17265.176792        1.956396  0.193561  10.107378
# 27366  AT5G67610   1938.263024        0.327128  0.115330   2.836467
# 27367  AT5G67620   1305.623526       -1.459157  0.163689  -8.914178
# 27368  AT5G67630   2565.535088        0.065068  0.116319   0.559398
# 27369  AT5G67640    270.795090       -0.169226  0.161161  -1.050041
#
#              pvalue          padj        Gene
# 0      8.634049e-15  7.203149e-14      NAC001
# 1      2.130821e-02  4.121231e-02        ARV1
# 2      1.066631e-01  1.673376e-01        NGA3
# 3      5.415823e-09  2.826062e-08        DCL1
# 4      7.848588e-02  1.290246e-01  ath-MIR838
# ...             ...           ...         ...
# 27365  5.123711e-24  7.698072e-23        WIH1
# 27366  4.561573e-03  1.036210e-02   AT5G67610
# 27367  4.914496e-19  5.519193e-18   AT5G67620
# 27368  5.758900e-01  6.704053e-01   AT5G67630
# 27369  2.936992e-01  3.937147e-01   AT5G67640
#
# [21511 rows x 8 columns]

# %% [markdown]
# Ranking of genes

# %%
df['Rank'] = -np.log10(df.padj)*df.log2FoldChange

df = df.sort_values('Rank', ascending = False).reset_index(drop = True)

df
# Out:
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#           Geneid      baseMean  log2FoldChange     lfcSE       stat  \
# 0      AT3G15670  12370.735742        9.218518  0.210769  43.737529
# 1      AT5G06760  24237.548165        7.856435  0.195181  40.251970
# 2      AT5G52300  10239.269607        8.464562  0.188816  44.829676
# 3      AT1G52690  32143.745842        8.725479  0.211339  41.286669
# 4      AT2G47770   6231.121662        8.337546  0.230843  36.117877
# ...          ...           ...             ...       ...        ...
# 21506  AT1G13420   7325.602762       -4.255109  0.124369 -34.213527
# 21507  AT2G45180   3331.219314       -6.342608  0.206506 -30.713925
# 21508  AT5G53250  11173.758610       -5.918747  0.160964 -36.770635
# 21509  AT4G14130   5594.441877       -5.496272  0.134128 -40.977876
# 21510  AT1G65310   4971.366359       -6.947470  0.147875 -46.982189
#
#               pvalue           padj       Gene         Rank
# 0       0.000000e+00   0.000000e+00  AT3G15670          inf
# 1       0.000000e+00   0.000000e+00     LEA4-5          inf
# 2       0.000000e+00   0.000000e+00      LTI65          inf
# 3       0.000000e+00   0.000000e+00       LEA7          inf
# 4      1.188747e-285  2.528033e-282       TSPO  2347.829713
# ...              ...            ...        ...          ...
# 21506  1.521661e-256  2.327540e-253       ST4B -1074.981464
# 21507  3.709751e-207  3.099364e-204  AT2G45180 -1290.776069
# 21508  5.442075e-296  1.414516e-292      AGP22 -1727.382727
# 21509   0.000000e+00   0.000000e+00      XTH15         -inf
# 21510   0.000000e+00   0.000000e+00      XTH17         -inf
#
# [21511 rows x 9 columns]

# %%
ranking = df[['Gene', 'Rank']]
ranking
# Out:
#             Gene         Rank
# 0      AT3G15670          inf
# 1         LEA4-5          inf
# 2          LTI65          inf
# 3           LEA7          inf
# 4           TSPO  2347.829713
# ...          ...          ...
# 21506       ST4B -1074.981464
# 21507  AT2G45180 -1290.776069
# 21508      AGP22 -1727.382727
# 21509      XTH15         -inf
# 21510      XTH17         -inf
#
# [21511 rows x 2 columns]

# %% [markdown]
# Cleaning the dataset

# %%
ranking_clean = ranking.replace([float('inf'), float('-inf')], pd.NA).dropna()

# %%
ordered_genes = (
    ranking_clean.sort_values("Rank", ascending=False)["Gene"]
    .tolist()
)

# %% [markdown]
# GSEA

# %%
# !pip install gprofiler-official
# Out:
# Requirement already satisfied: gprofiler-official in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from gprofiler-official) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->gprofiler-official) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->gprofiler-official) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->gprofiler-official) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->gprofiler-official) (2025.10.5)

# %%
from gprofiler import GProfiler

# %%
gp = GProfiler(return_dataframe=True)

gsea_results = gp.profile(
    organism='athaliana',
    query=ordered_genes,
    ordered=True,
    no_evidences=False,
    sources=['GO:BP', 'GO:MF', 'GO:CC', 'KEGG']
)

# %%
gsea_results.head(20)
# Out:
#    source      native                                          name  \
# 0   GO:BP  GO:0042221                          response to chemical
# 1   GO:BP  GO:0009628                  response to abiotic stimulus
# 2   GO:BP  GO:0050896                          response to stimulus
# 3   GO:BP  GO:1901700        response to oxygen-containing compound
# 4   GO:BP  GO:0006950                            response to stress
# 5   GO:BP  GO:0071456                  cellular response to hypoxia
# 6   GO:BP  GO:0036294  cellular response to decreased oxygen levels
# 7   GO:BP  GO:0071453            cellular response to oxygen levels
# 8   GO:BP  GO:0009415                             response to water
# 9   GO:BP  GO:0001666                           response to hypoxia
# 10  GO:BP  GO:0036293           response to decreased oxygen levels
# 11  GO:BP  GO:0001101                     response to acid chemical
# 12  GO:BP  GO:0009414                 response to water deprivation
# 13  GO:BP  GO:0070482                     response to oxygen levels
# 14  GO:BP  GO:0009737                     response to abscisic acid
# 15  GO:BP  GO:0097305                           response to alcohol
# 16  GO:BP  GO:0006970                    response to osmotic stress
# 17  GO:BP  GO:0070887        cellular response to chemical stimulus
# 18  GO:BP  GO:0033993                             response to lipid
# 19  GO:MF  GO:0043565                 sequence-specific DNA binding
#
#          p_value  significant  \
# 0   5.290231e-51         True
# 1   8.451702e-48         True
# 2   6.150648e-35         True
# 3   3.481114e-31         True
# 4   1.199467e-30         True
# 5   2.427751e-30         True
# 6   4.736039e-30         True
# 7   4.736039e-30         True
# 8   1.866612e-28         True
# 9   2.979559e-28         True
# 10  9.662562e-28         True
# 11  1.036611e-27         True
# 12  1.079628e-27         True
# 13  1.291407e-27         True
# 14  3.197301e-27         True
# 15  1.140850e-26         True
# 16  8.805425e-26         True
# 17  8.772432e-25         True
# 18  3.808006e-22         True
# 19  4.893370e-22         True
#
#                                           description  term_size  query_size  \
# 0   "Any process that results in a change in state...       2940        1467
# 1   "Any process that results in a change in state...       2131        1709
# 2   "Any process that results in a change in state...       6001        1719
# 3   "Any process that results in a change in state...       1659         651
# 4   "Any process that results in a change in state...       3733         669
# 5   "Any process that results in a change in state...        239        1574
# 6   "Any process that results in a change in state...        241        1574
# 7   "Any process that results in a change in state...        241        1574
# 8   "Any process that results in a change in state...        436        1709
# 9   "Any process that results in a change in state...        266        1574
# 10  "Any process that results in a change in state...        270        1574
# 11  "Any process that results in a change in state...        464        1709
# 12  "Any process that results in a change in state...        424        1709
# 13  "Any process that results in a change in state...        271        1574
# 14  "Any process that results in a change in state...        604        1073
# 15  "Any process that results in a change in state...        613        1073
# 16  "Any process that results in a change in state...        537         806
# 17  "Any process that results in a change in state...       1669        1687
# 18  "Any process that results in a change in state...       1022        1133
# 19  "Binding to DNA of a specific nucleotide compo...       1038        1969
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 0                 412                  21925   0.280845  0.140136  query_1
# 1                 363                  21925   0.212405  0.170343  query_1
# 2                 706                  21925   0.410704  0.117647  query_1
# 3                 146                  21925   0.224270  0.088005  query_1
# 4                 241                  21925   0.360239  0.064559  query_1
# 5                  80                  21925   0.050826  0.334728  query_1
# 6                  80                  21925   0.050826  0.331950  query_1
# 7                  80                  21925   0.050826  0.331950  query_1
# 8                 113                  21925   0.066121  0.259174  query_1
# 9                  82                  21925   0.052097  0.308271  query_1
# 10                 82                  21925   0.052097  0.303704  query_1
# 11                116                  21925   0.067876  0.250000  query_1
# 12                110                  21925   0.064365  0.259434  query_1
# 13                 82                  21925   0.052097  0.302583  query_1
# 14                104                  21925   0.096925  0.172185  query_1
# 15                104                  21925   0.096925  0.169657  query_1
# 16                 82                  21925   0.101737  0.152700  query_1
# 17                254                  21925   0.150563  0.152187  query_1
# 18                136                  21925   0.120035  0.133072  query_1
# 19                190                  22878   0.096496  0.183044  query_1
#
#                                  parents  \
# 0                           [GO:0050896]
# 1                           [GO:0050896]
# 2                           [GO:0008150]
# 3                           [GO:0042221]
# 4                           [GO:0050896]
# 5   [GO:0001666, GO:0033554, GO:0036294]
# 6               [GO:0036293, GO:0071453]
# 7               [GO:0070482, GO:0070887]
# 8   [GO:0001101, GO:0009628, GO:1901700]
# 9               [GO:0006950, GO:0036293]
# 10                          [GO:0070482]
# 11                          [GO:0042221]
# 12              [GO:0006950, GO:0009415]
# 13                          [GO:0009628]
# 14  [GO:0009725, GO:0033993, GO:0097305]
# 15                          [GO:1901700]
# 16              [GO:0006950, GO:0009628]
# 17              [GO:0042221, GO:0051716]
# 18                          [GO:0042221]
# 19                          [GO:0003677]
#
#                                         intersections  \
# 0   [TSPO, AT3G02480, AT3G17520, ADH1, LTI78, AT4G...
# 1   [TSPO, AT3G02480, AT3G17520, ADH1, LTI78, NCED...
# 2   [TSPO, AT3G02480, AT3G17520, ADH1, LTI78, AT4G...
# 3   [TSPO, AT3G02480, AT3G17520, ADH1, LTI78, NCED...
# 4   [TSPO, AT3G02480, AT3G17520, ADH1, LTI78, AT4G...
# 5   [ADH1, SUS1, STZ, AT5G35735, BCB, TCH3, SRC2, ...
# 6   [ADH1, SUS1, STZ, AT5G35735, BCB, TCH3, SRC2, ...
# 7   [ADH1, SUS1, STZ, AT5G35735, BCB, TCH3, SRC2, ...
# 8   [AT3G02480, AT3G17520, ADH1, LTI78, NCED3, SUS...
# 9   [ADH1, SUS1, STZ, AT5G35735, BCB, TCH3, SRC2, ...
# 10  [ADH1, SUS1, STZ, AT5G35735, BCB, TCH3, SRC2, ...
# 11  [AT3G02480, AT3G17520, ADH1, LTI78, NCED3, SUS...
# 12  [AT3G02480, AT3G17520, ADH1, LTI78, NCED3, SUS...
# 13  [ADH1, SUS1, STZ, AT5G35735, BCB, TCH3, SRC2, ...
# 14  [TSPO, ADH1, LTI78, SAG29, AT5G52050, STZ, AT5...
# 15  [TSPO, ADH1, LTI78, SAG29, AT5G52050, STZ, AT5...
# 16  [TSPO, ADH1, LTI78, NCED3, SUS1, SAG29, STZ, A...
# 17  [ADH1, AT4G36430, SUS1, SAG29, STZ, AT5G35735,...
# 18  [TSPO, ADH1, LTI78, SAG29, AT5G52050, STZ, AT5...
# 19  [STZ, MYB305, WRKY23, HB-12, MYB41, AT4G18650,...
#
#                                             evidences
# 0   [[IEP], [IEP], [IEP], [IMP, IEP, HEP], [IEP, I...
# 1   [[IEP], [IEP], [IEP], [IDA, IMP, IGI, IEP, HEP...
# 2   [[IEP], [IEP], [IEP], [IDA, IMP, IGI, IEP, HEP...
# 3   [[IEP], [IEP], [IEP], [IEP], [IEP, IEA], [IMP]...
# 4   [[IEP], [IEP], [IEP], [IDA, IMP, IGI, IEP, HEP...
# 5   [[IMP, HEP], [HEP], [HEP], [HEP], [HEP], [HEP]...
# 6   [[IMP, HEP], [HEP], [HEP], [HEP], [HEP], [HEP]...
# 7   [[IMP, HEP], [HEP], [HEP], [HEP], [HEP], [HEP]...
# 8   [[IEP], [IEP], [IEP], [IEP], [IMP], [IEP], [IM...
# 9   [[IDA, IMP, IEP, HEP], [IEP, HEP], [HEP], [HEP...
# 10  [[IDA, IMP, IEP, HEP], [IEP, HEP], [HEP], [HEP...
# 11  [[IEP], [IEP], [IEP], [IEP], [IMP], [IEP], [IM...
# 12  [[IEP], [IEP], [IEP], [IEP], [IMP], [IEP], [IM...
# 13  [[IDA, IMP, IEP, HEP], [IEP, HEP], [HEP], [HEP...
# 14  [[IEP], [IEP], [IEP, IEA], [IEP], [IEP], [IEP]...
# 15  [[IEP], [IEP], [IEP, IEA], [IEP], [IEP], [IEP]...
# 16  [[IEP], [IGI, IEP], [IGI, IEP], [IMP], [IEP], ...
# 17  [[IMP, HEP], [IEA], [HEP], [IMP, IEP], [HEP], ...
# 18  [[IEP], [IEP], [IEP, IEA], [IEP], [IEP], [IEP]...
# 19  [[IDA, IPI], [IPI, IEA], [IPI, IEA], [IPI, IEA...

# %%
gsea_results.to_csv("gprofiler_gsea_results.csv", index=False)

# %% [markdown]
# Visualization

# %%
# !pip install plotnine
# Out:
# Requirement already satisfied: plotnine in /usr/local/lib/python3.12/dist-packages (0.14.5)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (3.10.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (2.2.2)
# Requirement already satisfied: mizani~=0.13.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (0.13.5)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from plotnine) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (0.14.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->plotnine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->plotnine) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.0->plotnine) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->plotnine) (1.17.0)

# %%
from plotnine import *

# %%
df = gsea_results.copy()
df["GeneRatio"] = df["intersection_size"] / df["term_size"]
df["neglog10"] = -np.log10(df["p_value"])

# Sort by Count (intersection_size) descending
df = df.sort_values("intersection_size", ascending=False).head(12)

(
    ggplot(df, aes("GeneRatio", "reorder(name, intersection_size)"))  # sort by count
    + geom_point(
        aes(size="intersection_size", color="neglog10"),
        alpha=0.8
    )
    + scale_color_gradient(low="lightpink", high="red")
    + scale_size(range=[3, 12])
    + theme_bw()
    + theme(
        figure_size=(8, 6),
        axis_title=element_text(size=14),
        axis_text=element_text(size=10),
        panel_grid_major_x=element_line(color="gray", linetype="dashed", size=0.3)
    )
    + labs(
        x="GeneRatio",
        y="GO Term",
        color="-log10(p-value)",
        size="Count",
        title="Bouble Plot"
    )
)

# %%
(
    ggplot(df, aes("reorder(name, intersection_size)", "intersection_size", fill="neglog10"))
    + geom_col()
    + coord_flip()
    + scale_fill_gradient(low="lightblue", high="darkred")
    + theme_bw()
    + theme(
        figure_size=(8, 6),
        axis_title=element_text(size=14),
        axis_text=element_text(size=10),
    )
    + labs(
        x="GO Term",
        y="Count",
        fill="-log10(p-value)",
        title="Bar Plot"
    )
)

# %% [markdown]
# EMAP from gprofiler

# %% [markdown]
# Data Preparation

# %%
import ast

# %%
top20 = gsea_results.sort_values("p_value").head(20).copy()
top20["neglog10_p"] = -np.log10(top20["p_value"])

# %%
df = top20.copy()

# Convert gene list strings → list
df["intersections"] = df["intersections"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# Add −log10 p-value
df["neglog10_p"] = -np.log10(df["p_value"])

# %% [markdown]
# Compute Gene-Set Similarity (Jaccard Index)

# %%
import itertools

def jaccard(a, b):
    a, b = set(a), set(b)
    if len(a.union(b)) == 0:
        return 0
    return len(a.intersection(b)) / len(a.union(b))

edges = []

# Compute pairwise similarity
for i, j in itertools.combinations(df.index, 2):
    sim = jaccard(df.loc[i, "intersections"], df.loc[j, "intersections"])
    if sim >= 0.2:   # threshold (adjustable)
        edges.append((i, j, sim))

# %% [markdown]
# Build graph using networkx

# %%
import networkx as nx

# %%
G = nx.Graph()

# Add nodes
for idx, row in df.iterrows():
    G.add_node(
        idx,
        label=row["name"],
        size=row["intersection_size"],
        color=row["neglog10_p"]
    )

# Add similarity edges
for i, j, sim in edges:
    G.add_edge(i, j, weight=sim)

# %% [markdown]
# Plot EMAP (Network Plot)

# %%
plt.figure(figsize=(16, 14))

# Graph layout
pos = nx.spring_layout(G, k=0.7, seed=42)

# Node sizes
sizes = [G.nodes[n]["size"] * 10 for n in G.nodes]

# Node colors
colors = [G.nodes[n]["color"] for n in G.nodes]

# Draw edges
nx.draw_networkx_edges(G, pos, alpha=0.3)

# Draw nodes
nodes = nx.draw_networkx_nodes(
    G,
    pos,
    node_size=sizes,
    node_color=colors,
    cmap="coolwarm_r"
)

# Draw labels
nx.draw_networkx_labels(
    G,
    pos,
    labels={n: G.nodes[n]["label"] for n in G.nodes},
    font_size=8
)

plt.colorbar(nodes, label="-log10(p-value)")

plt.margins(0.3)

plt.tight_layout()

plt.title("EMAP – Enrichment Map from g:Profiler Results")
plt.axis("off")
plt.show()
